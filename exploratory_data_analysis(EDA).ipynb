# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcusreu1/DataScienceToolkit/blob/main/exploratory_data_analysis(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA
# exploratory data analysis
# el analisis exploratorio de la data es una parte escencial para comprender con que tipo de datos estamos trabajando y cuales son las caracteristicas de esta

# %% [markdown]
# #Paso 1
# ##obtención de datos
# para empezar con esta explicacion primero descargaremos la data

# %%
#primero importamos la libreria necesaria
import pandas as pd

#leemos la data con pd.read_csv
df= pd.read_csv("datos_paises.csv")

# %% [markdown]
# #paso 2
# el primer paso en el analisis exploratorio es revisar el contenido

# %%
#ver las primeras 5 filas del dataframe, esto se hace para poder ver una vista previa
df.head()

#tambien puedes usar sample para ver valores random
df.sample(5)
# Out:
#             pais continente       km2  poblacion_miles
# 12   Philippines       Asia  300000.0           104918
# 58        Malawi     Africa  118484.0            18622
# 139        Qatar       Asia   11607.0             2639
# 140      Namibia     Africa  824116.0             2534
# 201      Bermuda    America      53.0               61

# %%
#ver los valores de la media, desviacion media, min, 1/4 2/4 3/4 y max de los valores numericos
df.describe()
# Out:
#                 km2  poblacion_miles
# count  2.280000e+02     2.290000e+02
# mean   5.880081e+05     3.275679e+04
# std    1.788950e+06     1.332751e+05
# min    1.000000e+00     1.000000e+00
# 25%    3.710500e+03     4.310000e+02
# 50%    8.356700e+04     5.448000e+03
# 75%    4.359325e+05     1.919300e+04
# max    1.709825e+07     1.409517e+06

# %%
#ver el contenido de una columna con unique, en este caso los paises
df['pais'].unique()
#en este caso el continente
df['continente'].unique()
#contar los valores unicos
#df['pais'].nunique()
# Out:
# array(['Asia', 'America', 'Africa', 'Europa', 'Oceania'], dtype=object)

# %%
#contar valores de una columna
df['pais'].value_counts()
df['km2'].value_counts()
# Out:
# 457.0        2
# 180.0        2
# 1.0          2
# 9600000.0    1
# 28052.0      1
#             ..
# 1098581.0    1
# 27750.0      1
# 27830.0      1
# 48671.0      1
# 12.0         1
# Name: km2, Length: 225, dtype: int64

# %% [markdown]
# #paso 3
# ver la distribucion de los datos con graficos

# %%
#grafico de pastel
import matplotlib.pyplot as plt
plt.pie(df['continente'].value_counts(), labels=['Asia', 'America', 'Africa', 'Europa', 'Oceania'], autopct= "%0.2f")
plt.show()

# %%
#ver el histograma
import seaborn as sns
sns.histplot(df[df['continente']== 'Africa']['km2'])
sns.histplot(df[df['continente']== 'Europa']['km2'])
sns.histplot(df[df['continente']== 'Oceania']['km2'])
sns.histplot(df[df['continente']== 'Asia']['km2'])
sns.histplot(df[df['continente']== 'America']['km2'])
plt.show()

# %%
#ver distintos graficos de dispersion de los datos
sns.pairplot(df, hue='continente')

# %%
sns.heatmap(df.corr(), annot= True)
plt.show()
# Out:
# <ipython-input-42-525af6cc448f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot= True)

# %% [markdown]
# #conclusion
# en conclusion el analisis de datos es un paso importante y escencial a la hora de hacer un proyecto, en este cuaderno vimos lo que yo considero que puede ser mas importante para el analisis exploratorio que es ver el contenido del dataframe, las etiquetas de las columnas y la descripcion de los datos, con la media. ademas de tambien de hacer unas graficas para saber mas acerca de la distribucion

# %% [markdown]
# ![image.png](data:image/png;base64,...)
